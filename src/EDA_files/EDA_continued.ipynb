# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../../data/clean_data.csv')

# %%
# Filters data to only have one year of data for a specific grade and skill code 
# (will be used to create a filter for the final data)
filtered_data = data[data.year_start == 2018]
filtered_data = filtered_data[filtered_data.grade == 4]
filtered_data = filtered_data[filtered_data['sub_population'].isin(['ABORIGINAL', 'NON ABORIGINAL'])]

filtered_data_num = filtered_data[filtered_data.fsa_skill_code == 'Numeracy']

# %%
# Fill a list with the school numbers of schools with both Aboriginal and Non Aboriginal students
num_filter = []
for i in data.school_number.unique():
    if filtered_data_num[filtered_data_num.school_number == i].count()['score'] == 2:
        num_filter.append(i)

# %%
# Apply the filter for schools with both Aboriginal and Non Aboriginal students
schools_with_both = data[data.school_number.isin(num_filter)]

# %%
schools_with_only_one = data[~data.school_number.isin(num_filter)]

# %%
for i in range(len(data)):
    if data.iloc[i].school_number in num_filter:
        data['has_both'] = 1
    else:
        data['has_both'] = 0

# %%
data.tail()
# Out:
#         Unnamed: 0    data_level  public_or_independent  district_number  \
# 329297      329298  SCHOOL LEVEL  BC Independent School              NaN
# 329298      329299  SCHOOL LEVEL  BC Independent School              NaN
# 329299      329300  SCHOOL LEVEL  BC Independent School              NaN
# 329300      329301  SCHOOL LEVEL  BC Independent School              NaN
# 329301      329302  SCHOOL LEVEL  BC Independent School              NaN
#
#                                             district_name  school_number  \
# 329297  Chief & Council of Gwa'sala-'Nakwaxda'xw (IATH...      8597142.0
# 329298  Chief & Council of Gwa'sala-'Nakwaxda'xw (IATH...      8597142.0
# 329299         Nak'al Bun Education Society (IATHNBR:411)      9197495.0
# 329300         Nak'al Bun Education Society (IATHNBR:411)      9197495.0
# 329301         Nak'al Bun Education Society (IATHNBR:411)      9197495.0
#
#                          school_name                sub_population  \
# 329297  Gwa'sala-'Nakwaxda'xw School                    ABORIGINAL
# 329298  Gwa'sala-'Nakwaxda'xw School  NON ENGLISH LANGUAGE LEARNER
# 329299   Nak'albun Elementary School                  ALL STUDENTS
# 329300   Nak'albun Elementary School                    ABORIGINAL
# 329301   Nak'albun Elementary School  NON ENGLISH LANGUAGE LEARNER
#
#        fsa_skill_code  grade  number_expected_writers  number_writers  score  \
# 329297        Writing      7                       13              10    2.1
# 329298        Writing      7                       13              10    2.1
# 329299        Writing      7                       15              14    2.0
# 329300        Writing      7                       13              12    2.0
# 329301        Writing      7                       15              14    2.0
#
#         year_start  year_end  has_both
# 329297        2018      2019         1
# 329298        2018      2019         1
# 329299        2018      2019         1
# 329300        2018      2019         1
# 329301        2018      2019         1

# %%
schools_with_both.head()
# Out:
#      Unnamed: 0    data_level public_or_independent  district_number  \
# 415         415  SCHOOL LEVEL      BC Public School              5.0
# 416         416  SCHOOL LEVEL      BC Public School              5.0
# 417         417  SCHOOL LEVEL      BC Public School              5.0
# 418         418  SCHOOL LEVEL      BC Public School              5.0
# 419         419  SCHOOL LEVEL      BC Public School              5.0
#
#           district_name  school_number          school_name  sub_population  \
# 415  Southeast Kootenay       502031.0  Steeples Elementary    ALL STUDENTS
# 416  Southeast Kootenay       502031.0  Steeples Elementary          FEMALE
# 417  Southeast Kootenay       502031.0  Steeples Elementary            MALE
# 418  Southeast Kootenay       502031.0  Steeples Elementary      ABORIGINAL
# 419  Southeast Kootenay       502031.0  Steeples Elementary  NON ABORIGINAL
#
#     fsa_skill_code  grade  number_expected_writers  number_writers      score  \
# 415       Numeracy      4                       38              36  411.27778
# 416       Numeracy      4                       23              22  442.27273
# 417       Numeracy      4                       15              14  362.57143
# 418       Numeracy      4                       11              10  439.60000
# 419       Numeracy      4                       27              26  400.38462
#
#      year_start  year_end
# 415        2007      2008
# 416        2007      2008
# 417        2007      2008
# 418        2007      2008
# 419        2007      2008

# %%
schools_with_only_one.head()
# Out:
#    Unnamed: 0    data_level public_or_independent  district_number  \
# 0           0  SCHOOL LEVEL      BC Public School              5.0
# 1           1  SCHOOL LEVEL      BC Public School              5.0
# 2           2  SCHOOL LEVEL      BC Public School              5.0
# 3           3  SCHOOL LEVEL      BC Public School              5.0
# 4           4  SCHOOL LEVEL      BC Public School              5.0
#
#         district_name  school_number                school_name  \
# 0  Southeast Kootenay       501007.0  Jaffray Elem-Jr Secondary
# 1  Southeast Kootenay       501007.0  Jaffray Elem-Jr Secondary
# 2  Southeast Kootenay       501007.0  Jaffray Elem-Jr Secondary
# 3  Southeast Kootenay       501007.0  Jaffray Elem-Jr Secondary
# 4  Southeast Kootenay       501007.0  Jaffray Elem-Jr Secondary
#
#                  sub_population fsa_skill_code  grade  \
# 0                  ALL STUDENTS       Numeracy      4
# 1                NON ABORIGINAL       Numeracy      4
# 2  NON ENGLISH LANGUAGE LEARNER       Numeracy      4
# 3                  ALL STUDENTS       Numeracy      4
# 4                NON ABORIGINAL       Numeracy      4
#
#    number_expected_writers  number_writers      score  year_start  year_end
# 0                       18              18  464.27778        2007      2008
# 1                       16              16  468.87500        2007      2008
# 2                       18              18  464.27778        2007      2008
# 3                       18              18  531.55556        2008      2009
# 4                       18              18  531.55556        2008      2009

# %%
# Save the filtered data to a csv file
schools_with_both.to_csv('schools_with_both.csv')

# %%
schools_with_only_one.to_csv('schools_with_only_one.csv')

# %%
num_filter = [1,2,3]
has_both = pd.DataFrame()
has_both['school_number'] = num_filter
has_both['has_both'] = 1

# %%
has_both
# Out:
#    school_number  has_both
# 0              1         1
# 1              2         1
# 2              3         1

# %%
test = pd.DataFrame([9,8,8],[1,2,4],)
test
# Out:
#    0
# 1  9
# 2  8
# 4  8

# %%
result = test.merge(has_both, left_on='school_number')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-3a3f098e45ee> in <module>
# ----> 1 result = test.merge(has_both, left_on='school_number')
#
# /opt/miniconda3/envs/mds/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# /opt/miniconda3/envs/mds/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# /opt/miniconda3/envs/mds/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# /opt/miniconda3/envs/mds/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1221                     )
#    1222                 self.left_on = [None] * n
# -> 1223         if len(self.right_on) != len(self.left_on):
#    1224             raise ValueError("len(right_on) must equal len(left_on)")
#    1225
#
# TypeError: object of type 'NoneType' has no len()
